# %%
import numpy as np
import pandas as pd

# %%
diabetes_dataset = pd.read_csv('Datasets/final_diabetes_disease_dataSet.csv')

# %%
diabetes_dataset.head()
# Out:
#    Unnamed: 0  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0           0      148             72             35        0  33.6
# 1           1       85             66             29        0  26.6
# 2           2      183             64              0        0  23.3
# 3           3       89             66             23       94  28.1
# 4           4      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
diabetes_dataset = diabetes_dataset.drop(labels='Unnamed: 0',axis=1)

# %%
diabetes_dataset.describe()
# Out:
#           Glucose  BloodPressure  SkinThickness     Insulin         BMI  \
# count  768.000000     768.000000     768.000000  768.000000  768.000000
# mean   120.894531      69.105469      20.536458   79.799479   31.992578
# std     31.972618      19.355807      15.952218  115.244002    7.884160
# min      0.000000       0.000000       0.000000    0.000000    0.000000
# 25%     99.000000      62.000000       0.000000    0.000000   27.300000
# 50%    117.000000      72.000000      23.000000   30.500000   32.000000
# 75%    140.250000      80.000000      32.000000  127.250000   36.600000
# max    199.000000     122.000000      99.000000  846.000000   67.100000
#
#        DiabetesPedigreeFunction         Age     Outcome
# count                768.000000  768.000000  768.000000
# mean                   0.471876   33.240885    0.348958
# std                    0.331329   11.760232    0.476951
# min                    0.078000   21.000000    0.000000
# ...

# %%
heart_dataset = pd.read_csv('Datasets/final_heart_disease_dataSet.csv')

# %%
heart_dataset.head()
# Out:
#    Unnamed: 0  age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  \
# 0         937   65    0   2       140   417    1        0      157      0
# 1         289   55    0   0       128   205    0        2      130      1
# 2          93   54    0   1       132   288    1        0      159      1
# 3         134   41    0   1       126   306    0        1      163      0
# 4         444   43    1   0       115   303    0        1      181      0
#
#    oldpeak  slope  ca  thal  target
# 0      0.8      2   1     2       1
# 1      2.0      1   1     3       0
# 2      0.0      2   1     2       1
# 3      0.0      2   0     2       1
# 4      1.2      1   0     2       1

# %%
heart_dataset = heart_dataset.drop(labels='Unnamed: 0',axis=1)

# %%
heart_dataset.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   65    0   2       140   417    1        0      157      0      0.8      2
# 1   55    0   0       128   205    0        2      130      1      2.0      1
# 2   54    0   1       132   288    1        0      159      1      0.0      2
# 3   41    0   1       126   306    0        1      163      0      0.0      2
# 4   43    1   0       115   303    0        1      181      0      1.2      1
#
#    ca  thal  target
# 0   1     2       1
# 1   1     3       0
# 2   1     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart_dataset.shape
# Out:
# (1212, 14)

# %%
# !pip install pandas-Profiling
# Out:
# ...
#   Obtaining dependency information for visions[type_image_path]==0.7.4 from https://files.pythonhosted.org/packages/66/00/166b2beb8046f06b77a2bf2c1dafeb52eff608f7dd420c767d5f3ce36ef5/visions-0.7.4-py3-none-any.whl.metadata
#   Using cached visions-0.7.4-py3-none-any.whl.metadata (5.9 kB)
# ...
# Using cached visions-0.7.4-py3-none-any.whl (102 kB)
# ...
#   Attempting uninstall: visions
#     Found existing installation: visions 0.7.6
#     Uninstalling visions-0.7.6:
#       Successfully uninstalled visions-0.7.6
# ...
# WARNING: There was an error checking the latest version of pip.

# %%
conda install -c conda-forge pandas-profiling=2.6.0
# Out:
# Retrieving notices: ...working... done
# ...
# done
# Solving environment: unsuccessful initial attempt using frozen solve. Retrying with flexible solve.
# ...
# WARNING conda.models.version:get_matcher(556): Using .* with relational operator is superfluous and deprecated and will be removed in a future version of conda. Your spec was 1.9.0.*, but conda is ignoring the .* and treating it as 1.9.0
# WARNING conda.models.version:get_matcher(556): Using .* with relational operator is superfluous and deprecated and will be removed in a future version of conda. Your spec was 1.8.0.*, but conda is ignoring the .* and treating it as 1.8.0
# done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.7.4
#   latest version: 24.3.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=24.3.0
#
#
#
# ## Package Plan ##
#
# ...

# %%
from pandas_profiling import ProfileReport
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 from pandas_profiling import ProfileReport
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas_profiling/__init__.py:14
#      11 import numpy as np
#      12 from tqdm.auto import tqdm
# ---> 14 from pandas_profiling.model.messages import MessageType
#      15 from pandas_profiling.version import __version__
#      16 from pandas_profiling.utils.dataframe import rename_index
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas_profiling/model/messages.py:12
#       8 from dateutil.parser import parse
#      10 import numpy as np
# ---> 12 from pandas_profiling.model.correlations import perform_check_correlation
#      13 from pandas_profiling.config import config
#      14 from pandas_profiling.model.base import Variable
#
# ...

# %%
profile = ProfileReport(diabetes_dataset,explorative=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 profile = ProfileReport(diabetes_dataset,explorative=True)
#
# NameError: name 'ProfileReport' is not defined

# %%
profile.to_file('diabetes_EDA.html')

# %%
profile = ProfileReport(heart_dataset,explorative=True)

# %%
profile.to_file('Heart_EDA.html')
